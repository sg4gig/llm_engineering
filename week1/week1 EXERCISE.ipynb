# %% [markdown]
# # End of week 1 exercise
#
# To demonstrate your familiarity with OpenAI API, and also Ollama, build a tool that takes a technical question,
# and responds with an explanation. This is a tool that you will be able to use yourself during the course!

# %%
# imports
from openai import OpenAI
from IPython.display import Markdown, display, update_display

# %%
# constants
MODEL = 'qwen2.5:3b'
OLLAMA_BASE_URL = "http://localhost:11434/v1"
API_KEY="ollama"

# %%
# set up environment
ollama = OpenAI(base_url=OLLAMA_BASE_URL, api_key=API_KEY)

system_prompt="""
You are chatbot that acts as a tool that provides explanations to a technical question as a Tutor would do for a student.

"""

# %%
# here is the question; type over this to ask something new

question = """
Please explain what this means and why:
What is meant by paramaters in a ML model and how do they affect the model's performance?
"""

# %%
# Get gpt-4o-mini to answer, with streaming
def get_explanation():
    print(f"Getting explanation by streaming for question by calling {MODEL}")
    stream = ollama.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": question}
          ],
        stream=True
    )    
    response = ""
    display_handle = display(Markdown(""), display_id=True)
    for chunk in stream:
        response += chunk.choices[0].delta.content or ''
        update_display(Markdown(response), display_id=display_handle.display_id)

# %%
# Get Llama 3.2 to answer
get_explanation()
# Out:
# Getting explanation by streaming for question by calling qwen2.5:3b
# Certainly! Let's break down the concept of parameters in a machine learning model and how they influence its performance.
#
# ### What are Parameters in a Machine Learning Model?
#
# Parameters are essentially the set of values that define the model's structure and behavior. They are the adjustable numeric attributes that influence how the model is constructed and its ability to learn from the input data. Parameters directly affect how the model predicts or classifies new data points.
#
# In a machine learning model, these parameters are learned by the model during the training process. The process of training a model involves adjusting these parameters to minimize a loss function, which is a mathematical measurement of how well the model's predictions match the actual data.
#
# ### Types of Parameters in Models
#
# The type of parameters can vary depending on the model architecture. Here are some common examples:
# ...
